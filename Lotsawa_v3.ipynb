ཕགས། །ཉི་མ་རླབས་ཆེན་རྟ་ཞོན་རྒྱུ་བ་སྣང་བྱེད་གང་ཡིན་དང༌། །ཁུར་ལ་མི་རྩེག་ས་ཡིས་འཇིག་རྟེན་འདེགས་པ་གང་ཡིན་དེ། །རང་དོན་འགའ་མེད་ཆེན་པོ་རྣམས་ཀྱི་རང་བཞིན་དེ་འདྲ་སྟེ། །དེ་དག་འཇིག་རྟེན་ཕན་དང་བདེ་བའི་རོ་ལ་གཅིག་ཏུ་གཞོལ། །ཞེས་སོ།  །དེ་ལྟར་འགྲོ་བ་སྡུག་བསྔལ་གྱིས་ཀུན་ཏུ་གདུངས་པར་མཐོང་ནས་དེ་དག་གི་དོན་དུ་བྲེལ་བ་ལ་སྐྱེས་བུ་ཞེས་བྱ་ལ་མཁས་པ་ཞེས་ཀྱང་དེ་ལ་བྱ་སྟེ། '''

# 0.1. Название
strn=re.sub(r'([༄༅།\s]+\S+?ལས[།༔])\s+(\S+?་བཞུགས\S*[།༔]*)', '<h1 class="Toc">\\1 \\2</h1> <br><br>\\n\\n',strn, 0)

# 0.2. Тема - подзаголовок
strn=re.sub(r'(\S+?ནི[།༔])', '\\n<br><h4 class="Topic">\\1</h4><br>\\n',strn, 0)   

# 0.3. Новая глава
strn=re.sub(r'(༈)', '\\n\\n<br><br>\\1',strn)

# 0.4. Цитата до первого окончания
strn=re.sub(r'(\S+?ལས[༔།])\s+(.+?[༔།་]*)\s([།](ཞེས|ཅེས).+?[༔།]+)', '\\n<br><div class=\"cite_src\">\\1</div> <div class=\"cite\">\\2</div> <br>\\n\\3<br>\\n',strn, 0)

# 0.4. Цитата продолжение
strn=re.sub(r'([།](ཞེས|ཅེས).+?དང[༔།༌]*)(<br>\n)*\s*(.+?[༔།་]*)\s([།](ཞེས|ཅེས).+?[༔།]+)', '\\1\\3<div class="cite">\\4</div> <br>\\n\\5<br>\\n',strn, 0)

#0.5 Конец абзаца (заключающий помощник གོ ངོ དོ ནོ བོ མོ རོ ལོ སོ ཏོ после второго суффикса ད་; འོ་ - после слога без суффикса)
strn=re.sub(f'((ག་གོ|ང་ངོ[་]*|ད་དོ|ན་ནོ|བ་བོ|མ་མོ|ར་རོ|ལ་ལོ|ས་སོ|ད་ཏོ|འོ)([༔།{1,2}\s\t])+)[།\s]', '\\1<br><br>\\n\\n',strn)    

#0.6 Разделительные частицы
#strn=re.sub(f'(་)(གི|ཀྱི|གྱི|ཡི|གིས|ཀྱིས|གྱིས|ཡིས|སུ|རུ|ཏུ|ན|ལ|དུ|ཏེ|དེ|སྟེ|དང|ཞིང|ཅིང|ཤིང|ཀྱང|ཡང)([་།༔])', '\\1<dfn class="cc" title="сс">\\2</dfn>\\3',strn)    
#strn=re.sub(f'(འི|འིས|འང|འམ)|འང([་།༔])', '<dfn class="cc" title="сс">\\1\\2</dfn>',strn)    



print(strn)
# Out:
# <h1 class="Toc">༄༅། །སྐྱེས་བུ་ཆེན་པོའི་ལམ་གྱི་རིམ་པ་ལས། ཐེག་ཆེན་གྱི་འཇུག་སྒོ་སེམས་བསྐྱེད་བཞུགས་སོ༔</h1> <br><br>
# <div class="cite">།བདེ་དང་མི་བདེ་རྨི་ལམ་འདྲར་བགྲངས་ཤིང༌། །གཏི་མུག་སྐྱོན་གྱིས་དམའ་བའི་འགྲོ་མཐོང་ན། །ལས་ཀྱི་དམ་པ་གཞན་དོན་དགའ་བོར་ཞིང༌། །རང་གི་དོན་ལ་དེ་ཀོ་ཅི་སྟེ་བརྩོན།</div> <br>
# །ཞེས་གསུངས་པ་ལྟར་རོ།<br>
#   །དེ་ལྟར་རང་ཉིད་སྲིད་པའི་མཚོར་ལྷུང་བ་དང་འདྲ་བར་འགྲོ་བ་རྣམས་ཀྱང་བླང་དོར་འབྱེད་པའི་ཤེས་རབ་ཀྱི་མིག་ཟུམ་པས་ཉམ་ང་བ་དང་བྲལ་བའི་ཕྱོགས་སུ་བགྲོད་མི་ནུས་པར་གོམ་འགྲོས་འཁྱོར་བ་མཐོང་ན། རྒྱལ་བའི་རིགས་དང་ལྡན་པ་རྣམས་གཞན་ལ་བརྩེ་བ་མེད་པ་དང་དེ་དག་གི་དོན་དུ་མི་བརྩོན་པ་ནི་མི་རིགས་ཏེ།
# <br><div class="cite_src">།དེ་ཉིད་ལས།</div> <div class="cite">།ཤེས་རབ་མིག་ཟུམ་འགྲོས་འཁྱོར་གྱུར་པ་ལ། །འཇིག་རྟེན་དོན་སྒྲུབ་རྒྱལ་བའི་རྒྱལ་རིགས་ན། །སྙིང་རྗེ་མི་བསྐྱེད་སྐྱེས་བུ་གང་ཞིག་ཡོད། །དེ་དག་རྨོངས་བསལ་བརྩོན་འགྲུས་སུ་མི་རྩོམ།</div> <br>
# །ཞེས་སོ།<br>
#   །འདི་ན་སྐྱེས་བུ་རྣམས་ཀྱི་བདེ་བ་དང་བརྗིད་བག་དང་སྐྱེས་བུའི་རྩལ་ནི་གཞན་གྱི་དོན་ཁུར་དུ་འཁྱེར་བ་ལ་བྱ་བར་རིགས་ཏེ། རང་གི་དོན་ཙམ་ལ་དམིགས་པ་ནི་དུད་འགྲོ་རྣམས་དང་ཡང་ཐུན་མོང་བ་ཡིན་པའི་ཕྱིར་རོ། <br><br>
#
# དེའི་ཕྱིར་ཆེན་པོ་རྣམས་ཀྱི་ངང་ཚུལ་ནི་གཞན་གྱི་ཕན་བདེ་ལ་མཐའ་གཅིག་ཏུ་གཞོལ་བ་ཡིན་ཏེ།
# <br><div class="cite_src">།སློབ་མ་ལ་སྤྲིངས་པ་ལས།</div> <div class="cite">།ཤིན་ཏུ་རྙེད་སླའི་རྩྭ་ཁམ་འགའ་ལྟ་ཕྱུགས་ཀྱང་རང་ཉིད་ཟ། །ཤིན་ཏུ་སྐོམ་པས་གདུངས་པའང་ཆུ་ཞིག་རྙེད་ན་དགའ་མགུར་འཐུང༌། །འདི་ན་སྐྱེས་བུ་གཞན་དོན་བྱེད་པར་བརྩོན་པ་གང་ཡིན་པ། །དེ་འདིའི་བརྗིད་བག་ཡིན་ཏེ་དེ་བདེ་སྐྱེས་བུའི་རྩལ་དེ་འཕགས། །ཉི་མ་རླབས་ཆེན་རྟ་ཞོན་རྒྱུ་བ་སྣང་བྱེད་གང་ཡིན་དང༌། །ཁུར་ལ་མི་རྩེག་ས་ཡིས་འཇིག་རྟེན་འདེགས་པ་གང་ཡིན་དེ། །རང་དོན་འགའ་མེད་ཆེན་པོ་རྣམས་ཀྱི་རང་བཞིན་དེ་འདྲ་སྟེ། །དེ་དག་འཇིག་རྟེན་ཕན་དང་བདེ་བའི་རོ་ལ་གཅིག་ཏུ་གཞོལ།</div> <br>
# །ཞེས་སོ།<br>
#   །དེ་ལྟར་འགྲོ་བ་སྡུག་བསྔལ་གྱིས་ཀུན་ཏུ་གདུངས་པར་མཐོང་ནས་དེ་དག་གི་དོན་དུ་བྲེལ་བ་ལ་སྐྱེས་བུ་ཞེས་བྱ་ལ་མཁས་པ་ཞེས་ཀྱང་དེ་ལ་བྱ་སྟེ།

# %% [markdown]
# ##### 1. Разбираем строку для перевода

# %%
#1. отлепляем ->འི от слога
#for syl in ['འི', 'འིས', 'འང', 'འམ', 'འོ']: # исключил доп.строк - 'ར', 'འུ'  
#    strn=re.sub(f'([༄༅། ༿༧་|<\a-z>]*\S+?)({syl})([་༔།༾ཿ |]+)', r"\1་\2\3", strn)
    #print(strn) 

#2. Парсим Строку для перевода -> list список слов из строки 
strn_lst=re.findall(r'[༄༅།༼༽ ༿༧་༈|\"\'=<\a-z>]*(\S+?)[་༔༈།༾ཿ\s<\a-z>\"\'=/|]+', strn)

#3. присоединяем персонификаторы к пред слогу в -> strn_lst
for ind, syl in enumerate(strn_lst):
    if syl in ['པོ', 'བོ', 'མོ', 'ཀོ', 'ཅན', 'ལྡན', 'མཁན']: # исключил - མ, ཀ, ཁ, ག, པ, བ, 
        strn_lst[ind-1]=strn_lst[ind-1]+'་'+strn_lst.pop(ind)

# TODO Усложняем логику парсинга
#print(res_strn)
strn_lst=list(set(strn_lst))
strn_lst.sort(key=len, reverse=True) # сортируем - max_len в начало
print(strn_lst)
# Out:
# ['གཉིས་པོ', 'བསྐྱེད', 'བརྒྱུད', 'དང་ལྡན', 'སྤྲིངས', 'རིན་པོ', 'བསྒོམས', 'ཆེན་པོ', 'བསྐུལ', 'འཁྱོར', 'རྫོགས', 'འདིའི', 'ཕྱོགས', 'བསླབས', 'བརྟེན', 'བརྗིད', 'སྐྱོན', 'རླུབས', 'སྒྲུབ', 'བརྩོན', 'དམིགས', 'རྨོངས', 'འཐུང༌', 'རྒྱུན', 'བགྲོད', 'འགྲོས', 'སྤྱོད', 'འབྱེད', 'བགྲངས', 'གདུངས', 'ཕྱུགས', 'སྐྱེས', 'ཇོ་བོ', 'འདེགས', 'སྦྱུང', 'འགྲུས', 'བསྡུས', 'གསུངས', 'འཁྱེར', 'བཞུགས', 'དེ་ཀོ', 'ལྡོག', 'རིགས', 'བཞིན', 'བྲེལ', 'རྒྱས', 'ཤིང༌', 'བྱེད', 'ཞིང༌', 'རྣམས', 'པོའི', 'བུའི', 'ཕྱིན', 'མཐོང', 'ཅིང༌', 'རྟེན', 'སྙིང', 'རྩེག', 'གྱིས', '
# ##### 2. б) Ищем частицы в составе словосочетаний по словарю; в) Ищем словосочетания по строке

# %%
print(strn_lst)

# %%
#import re
# strn              исходная строка для перевода
# strn_lst          список слов из строки для перевода
# dct_ptcl          словарь частиц из Particles.yaml

# sent_lst          список сочетаний со словом из strn_lst
res_strn=strn     # копия исходной строка для перевода
res_dct={}        # словарь найденных вхождений sent в исход строку 

for ind, syl in enumerate(strn_lst): # по кажд уник слогу в strn_lst
    pattern=f'\'(\S*{syl}\S*?)[་།༔༈]*\':'
    #print('syl-',syl)

    # Б.Поиск по Dict.dict всех вариантов куда входит слог из strn_lst -> sent_lst[список_словосочетаний]
    sent_lst=list(set(re.findall(pattern, str(dct_ptcl))))
    sent_lst.sort(key=len, reverse=True) # сортируем - max_len в начало
    #print("сент_лст--", sent_lst)
    #lenth_res_lst=list(range(res_strn.count('་')+1))
    
    #В.Поиск по strn каждого уник из sent_lst в строке
    for sent in sent_lst:
        #print("сет-", sent)
        #ind=res_strn.find(sent)
        if sent in strn and sent not in res_dct: # если sent в исход строке И sent не находили ранее
            #strn=strn.replace('་'+str(sent)+'་','་|་') # из исход строки убираем найденное sent  
            strn=re.sub(f'([་།༽༼ ༿\s>]+)({str(sent)})([་༽༈།༔༾\s<]+)', r'\1|\3', strn)
            #if sent in ['ཡོད','པ', 'བ', 'བོ', 'ཀོ', 'ར']:# если sent-суффикс (не может идти сначала строки)  
            #    res_strn=re.sub(f'(\][་།  ༿]+)({sent})([་། ༔༾]+)', r'\1['+sent1+']\3', res_strn) #в дубль_строке заменяем sent 
            #else:
            #print (res_strn) 
            res_strn=re.sub(f'([་།༽༼\s༿>]+)({str(sent)})([་༽༈།༔༾\s<]+)', '\\1[\\2]\\3', res_strn, 0, re.MULTILINE) #в дубль_строке заменяем sent
                        
            res_dct[sent]=dct_ptcl[sent] # словарь найденных вхождений sent в исход строку

print (strn)
#res_strn=res_strn.replace('·', '་')
print (res_strn) 
#print(*res_dct.items(), sep="\n")
# Out:
# <h1 class="Toc">༄༅། །|་བུ་|་པོའི་|་|་རིམ་པ་|། |་|་|་|་སྒོ་སེམས་|་|༔</h1> <br><br>
#
#  |་སེམས་|་བ་|་|་སྲས་|་|་པ་སྤྱི་|་|་པའི་ཚུལ། །|་|་|་|་སྒོ་སེམས་|་ཁོ་ནར་|་པ། །བྱང་ཆུབ་སེམས་|་བ་རིམ་པ་|་ཇོ་བོ་|་བརྒྱུད་པ་རྒྱུ་འབྲས་མན་ངག་|།
# <br><h4 class="Topic">།|་བ་ལྷའི་གཞུང་|་|་|་སྦྱུང་བ་|།</h4><br>
#  །སེམས་|་|་|་པ་|་|་ཚུལ། །ཞར་|་གོ་རིམ་|་པ།
#
# <br><br>༈ |་བཙུན་|་པ་ཐུགས་|་|་པོ་|་|་པ་རྣམས་|་ཞབས་|་གུས་|་ཕྱག་|་ལོ། <br><br>
#
# %% [markdown]
# ##### 3. Создаем строки вывода с HTML тегами

# %%
dct_str=""
lst=list(dict.fromkeys(re.findall(r'\[(\S+?)\]', res_strn)))
print(lst)
cnt=1
for ind, k in enumerate(lst): # идем по строке    
    part_speech='na'
    if res_dct[k][0][0:2] == 'cc': 
        part_speech='cc'
        # создаем тэги для строки
    res_strn=res_strn.replace(f'[{k}]', f'<dfn class="{part_speech}" title="{res_dct[k]}"><a id="{cnt}_" href="#_{cnt}">{k}</a></dfn>')
        #создаем тэги для словарика
    dct_str+=f'<p id="_{cnt}">{cnt} <a lang="bo">{k}</a> = {res_dct[k]}</p>\n'#завернуть в тиб тег
    cnt+=1
print(res_strn)
print(dct_str)
# Out:
# ['སྐྱེས', 'ཆེན', 'ལམ', 'གྱི', 'ལས', 'ཐེག', 'འཇུག', 'བསྐྱེད', 'བཞུགས་སོ', 'སྨོན', 'སྦྱང', 'དང', 'རྒྱལ', 'ཀྱི', 'སྤྱོད', 'ལ', 'བསླབ', 'བསྟན', 'ནས', 'བདུན', 'ཞི', 'བརྟེན', 'ནི', 'སློབ', 'ངེས', 'རྗེ', 'དམ', 'ལྡན', 'པས', 'འཚལ', 'དེ', 'ལྟར', 'ཉེས', 'དམིགས', 'སྣ་ཚོགས', 'རིང', 'དུ', 'བསྒོམས', 'འབར', 'མཐོང', 'སྟེ', 'ཉོན', 'སྡུག', 'ཉེ', 'ཐོབ', 'འདོད', 'ཀྱིས', 'ཏུ', 'གདུངས', 'ཆེ', 'གསུམ', 'བསླབས', 'ན', 'གྲོལ', 'འཐོབ', 'ཡང', 'མཐོ', 'ལྡོག', 'ཀྱང', 'ཟད', 'རེ', 'གི', 'དོན', 'རྫོགས', 'སངས་རྒྱས', 'བསྐུལ', 'ཏེ', 'ཕྱིན', 'བསྡུས', 'འཇིག', 'སྒྲུབ', 'མེད', 'གཉིས', 'སྤང', 'བྱས', 'རྗེས', 'ཕན', 'གཅིག', 'བཞིན', 'དག', 'ཅེས', 'བགྲངས', 'གྱིས', 'འགྲོ', 'དགའ', 'བོར', 'ཅི་སྟེ', 'བརྩོན', 'ཞེས', 'གསུངས', 'འདྲ', 'བླང', 'དོར', 'འབྱེད', 'ཤེས་རབ', 'ང', 'བྲལ', 'སུ', 'བགྲོད', 'ནུས', 'བརྩེ', 'གྱུར', 'སྙིང་རྗེ', 'གང', 'ཞིག', 'ཡོད', 'རྨོངས', 'བསལ', 'འགྲུས', 'རྩོམ', 'འདི', 'བརྗིད', 'རྩལ', 'ཁུར', 'འཁྱེར', 'བྱ', 'ཙམ', 'གཞོལ', 'རྙེད', 'ལྟ', 'ཟ', 'སྐོམ', 'བྱེད', 'འཕགས', 'སྣང', 'ཡིས', 'འདེགས', 'དེ་འདྲ', 'མཁས']
# <h1 class="Toc">༄༅། །<dfn class="na" title="['be born; be produced; be engendered']"><a id="1_" href="#_1">སྐྱེས</a></dfn>་བུ་<dfn class="na" title="['big (size), great']"><a id="2_" href="#_2">ཆེན</a></dfn>་པོའི་<dfn class="na" title="['..или.', '.?', '.,', 'path; way; road; [connective particle:] and; or']"><a id="3_" href="#_3">ལམ</a></dfn>་<dfn class="cc" title="['cc', 'владение/принадлежность', 'соответствующее основе качество', 'место объекта', 'часть из/среди целого']"><a id="4_" href="#_4">གྱི</a></dfn>་རིམ་པ་<dfn class="na" title="['после', 'затем', 'деепричастие …ев/ув', 'среди различных', 'сравнит чем', 'action; deed; work; having (done something)']"><a id="5_" href="#_5">ལས</a></dfn>། <dfn class="na" title="['vehicle']"><a id="6_" href="#_6">ཐེག</a></dfn>་<dfn class="na" title="['big (size), great']"><a id="2_" href="#_2">ཆེན</a></dfn>་<dfn class="cc" title="['cc', 'владение/принадлежность', 'соответствующее основе качество', 'место объекта', 'часть из/среди целого']"><a id="4_" href="#_4">གྱི</a></dfn>་<dfn class="na" title="['enter; engage; apply; usher (into); engages']"><a id="7_" href="#_7">འཇུག</a></dfn>་སྒོ་སེམས་<dfn class="na" title="['generate; produce; engender']"><a id="8_" href="#_8">བསྐྱེད</a></dfn>་<dfn class="na" title="['так называется']"><a id="9_" href="#_9">བཞུགས་སོ</a></dfn>༔</h1> <br><br>
#
#  <dfn class="na" title="['wish; admire; pray; aspire']"><a id="10_" href="#_10">སྨོན</a></dfn>་སེམས་<dfn class="na" title="['to learn (present nh.), purify; wash; practice; train; clean;']"><a id="11_" href="#_11">སྦྱང</a></dfn>་བ་<dfn class="cc" title="['cc', 'собирание и разделение', 'по причине', '..непосредственно после', 'наставление/указание']"><a id="12_" href="#_12">དང</a></dfn>་<dfn class="na" title="['conquest; victory']"><a id="13_" href="#_13">རྒྱལ</a></dfn>་སྲས་<dfn class="cc" title="['cc', 'владение/принадлежность', 'соответствующее основе качество', 'место объекта', 'часть из/среди целого']"><a id="14_" href="#_14">ཀྱི</a></dfn>་<dfn class="na" title="['enjoy; make use of; practice; act out; perform; behavior; deeds; performance']"><a id="15_" href="#_15">སྤྱོད</a></dfn>་པ་སྤྱི་<dfn class="cc" title="['cc', ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки', 'идти']]"><a id="16_" href="#_16">ལ</a></dfn>་<dfn class="na" title="['to learn; teach; train in (present, past nh.)']"><a id="17_" href="#_17">བསླབ</a></dfn>་པའི་ཚུལ། །<dfn class="na" title="['vehicle']"><a id="6_" href="#_6">ཐེག</a></dfn>་<dfn class="na" title="['big (size), great']"><a id="2_" href="#_2">ཆེན</a></dfn>་<dfn class="cc" title="['cc', 'владение/принадлежность', 'соответствующее основе качество', 'место объекта', 'часть из/среди целого']"><a id="4_" href="#_4">གྱི</a></dfn>་<dfn class="na" title="['enter; engage; apply; usher (into); engages']"><a id="7_" href="#_7">འཇུག</a></dfn>་སྒོ་སེམས་<dfn class="na" title="['generate; produce; engender']"><a id="8_" href="#_8">བསྐྱེད</a></dfn>་ཁོ་ནར་<dfn class="na" title="['to show (past/present/future honorific)']"><a id="18_" href="#_18">བསྟན</a></dfn>་པ། །བྱང་ཆུབ་སེམས་<dfn class="na" title="['to learn (present nh.), purify; wash; practice; train; clean;']"><a id="11_" href="#_11">སྦྱང</a></dfn>་བ་རིམ་པ་<dfn class="cc" title="['cc', ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки', 'идти']]"><a id="16_" href="#_16">ལ</a></dfn>་ཇོ་བོ་<dfn class="na" title="['после', 'затем', 'деепричастие …ев/ув', 'среди подобных', 'от .. и до..']"><a id="19_" href="#_19">ནས</a></dfn>་བརྒྱུད་པ་རྒྱུ་འབྲས་མན་ངག་<dfn class="na" title="['seven']"><a id="20_" href="#_20">བདུན</a></dfn>།
# <br><h4 class="Topic">།<dfn class="na" title="['be peaceful; be calm; peace; pacification']"><a id="21_" href="#_21">ཞི</a></dfn>་བ་ལྷའི་གཞུང་<dfn class="cc" title="['cc', ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки', 'идти']]"><a id="16_" href="#_16">ལ</a></dfn>་<dfn class="na" title="['depend upon; rely; resort to; support']"><a id="22_" href="#_22">བརྟེན</a></dfn>་<dfn class="na" title="['после', 'затем', 'деепричастие …ев/ув', 'среди подобных', 'от .. и до..']"><a id="19_" href="#_19">ནས</a></dfn>་སྦྱུང་བ་<dfn class="na" title="['..-', '..касаемо']"><a id="23_" href="#_23">ནི</a></dfn>།</h4><br>
#  །སེམས་<dfn class="na" title="['generate; produce; engender']"><a id="8_" href="#_8">བསྐྱེད</a></dfn>་<dfn class="na" title="['после', 'затем', 'деепричастие …ев/ув', 'среди подобных', 'от .. и до..']"><a id="19_" href="#_19">ནས</a></dfn>་<dfn class="na" title="['enjoy; make use of; practice; act out; perform; behavior; deeds; performance']"><a id="15_" href="#_15">སྤྱོད</a></dfn>་པ་<dfn class="cc" title="['cc', ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки', 'идти']]"><a id="16_" href="#_16">ལ</a></dfn>་<dfn class="na" title="['to learn; teach; train in']"><a id="24_" href="#_24">སློབ</a></dfn>་ཚུལ། །ཞར་<dfn class="cc" title="['cc', ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки', 'идти']]"><a id="16_" href="#_16">ལ</a></dfn>་གོ་རིམ་<dfn class="na" title="['ascertain; ascertainment; certain']"><a id="25_" href="#_25">ངེས</a></dfn>་པ།
#
# <br><br>༈ <dfn class="na" title="['master; lord; leaders']"><a id="26_" href="#_26">རྗེ</a></dfn>་བཙུན་<dfn class="na" title="['..или..', '..?', '..,']"><a id="27_" href="#_27">དམ</a></dfn>་པ་ཐུགས་<dfn class="na" title="['master; lord; leaders']"><a id="26_" href="#_26">རྗེ</a></dfn>་<dfn class="na" title="['big (size), great']"><a id="2_" href="#_2">ཆེན</a></dfn>་པོ་<dfn class="cc" title="['cc', 'собирание и разделение', 'по причине', '..непосредственно после', 'наставление/указание']"><a id="12_" href="#_12">དང</a></dfn>་<dfn class="na" title="['обладающий', 'наделенный']"><a id="28_" href="#_28">ལྡན</a></dfn>་པ་རྣམས་<dfn class="cc" title="['cc', 'владение/принадлежность', 'соответствующее основе качество', 'место объекта', 'часть из/среди целого']"><a id="14_" href="#_14">ཀྱི</a></dfn>་ཞབས་<dfn class="cc" title="['cc', ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки', 'идти']]"><a id="16_" href="#_16">ལ</a></dfn>་གུས་<dfn class="na" title="['и так', '1.инструмент частица', '2.(vb. +--) потому что 3.(vb. +--) вопрос 4.в соответствии с', 'поскольку', 'когда']"><a id="29_" href="#_29">པས</a></dfn>་ཕྱག་<dfn class="na" title="['seek; want; ask; beg; beseech; desire; ; to understand']"><a id="30_" href="#_30">འཚལ</a></dfn>་ལོ། <br><br>
#
# <dfn class="cc" title="['cc', 'потому что', 'значит', '.. это так', 'потому что..', '.. - это ..', '.. - то что..']"><a id="31_" href="#_31">དེ</a></dfn>་<dfn class="na" title="['ābha', 'like; thus; in accordance with']"><a id="32_" href="#_32">ལྟར</a></dfn>་འཁོར་བའི་<dfn class="na" title="['bad; sin; evil; crime']"><a id="33_" href="#_33">ཉེས</a></dfn>་<dfn class="na" title="['to observe{D2}; apprehend; be aware of; object of observation (=dmigs pa)']"><a id="34_" href="#_34">དམིགས</a></dfn>་སྒོ་<dfn class="na" title="['varied, of different kinds, diversity']"><a id="35_" href="#_35">སྣ་ཚོགས</a></dfn>་<dfn class="na" title="['после', 'затем', 'деепричастие …ев/ув', 'среди подобных', 'от .. и до..']"><a id="19_" href="#_19">ནས</a></dfn>་རྒྱུན་<dfn class="na" title="['long time, tall, long, lengthwise']"><a id="36_" href="#_36">རིང</a></dfn>་<dfn class="cc" title="['cc', ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки']]"><a id="37_" href="#_37">དུ</a></dfn>་<dfn class="na" title="['meditate; meditatively cultivate']"><a id="38_" href="#_38">བསྒོམས</a></dfn>་པ་<dfn class="na" title="['после', 'затем', 'деепричастие …ев/ув', 'среди различных', 'сравнит чем', 'action; deed; work; having (done something)']"><a id="5_" href="#_5">ལས</a></dfn>་སྲིད་པ་ཐམས་ཅད་མེ་<dfn class="na" title="['burn; blaze up; blaze; catch fire; flaming; fire']"><a id="39_" href="#_39">འབར</a></dfn>་བའི་རླུབས་<dfn class="na" title="['ābha', 'like; thus; in accordance with']"><a id="32_" href="#_32">ལྟར</a></dfn>་<dfn class="na" title="['to see; to perceive (present/passive)']"><a id="40_" href="#_40">མཐོང</a></dfn>་<dfn class="cc" title="['cc', 'after--', 'having--', 'adverbal; потому что', 'значит', '.. это так', 'потому что..', '.. - это ..', '.. - то что..']"><a id="41_" href="#_41">སྟེ</a></dfn>། <dfn class="na" title="['affliction']"><a id="42_" href="#_42">ཉོན</a></dfn>་མོངས་པ་<dfn class="cc" title="['cc', 'собирание и разделение', 'по причине', '..непосредственно после', 'наставление/указание']"><a id="12_" href="#_12">དང</a></dfn>་<dfn class="na" title="['dear; kind; beloved']"><a id="43_" href="#_43">སྡུག</a></dfn>་བསྔལ་<dfn class="na" title="['near; dear; intimate']"><a id="44_" href="#_44">ཉེ</a></dfn>་བར་<dfn class="na" title="['be peaceful; be calm; peace; pacification']"><a id="21_" href="#_21">ཞི</a></dfn>་བའི་ཐར་པ་<dfn class="cc" title="['cc', ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки', 'идти']]"><a id="16_" href="#_16">ལ</a></dfn>་<dfn class="na" title="['attain; obtain; get, to win']"><a id="45_" href="#_45">ཐོབ</a></dfn>་<dfn class="na" title="['accept; assert; wish; desire; consider; to want (used with other verbs)']"><a id="46_" href="#_46">འདོད</a></dfn>་<dfn class="cc" title="['cc', 'деятель', 'инструмент', 'c отношением', 'По причине', 'из-за', 'вследствии']"><a id="47_" href="#_47">ཀྱིས</a></dfn>་ཡིད་ཀུན་<dfn class="cc" title="['cc', ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки']]"><a id="48_" href="#_48">ཏུ</a></dfn>་<dfn class="na" title="['torment; be tormented; be scorched; desire; long for']"><a id="49_" href="#_49">གདུངས</a></dfn>་པ་དེས། <dfn class="na" title="['..или.', '.?', '.,', 'path; way; road; [connective particle:] and; or']"><a id="3_" href="#_3">ལམ</a></dfn>་<dfn class="na" title="['to learn; teach; train in (present, past nh.)']"><a id="17_" hr ...
# <br><div class="cite_src">།ཕར་<dfn class="na" title="["went [past of 'gro, 'to go']"]"><a id="68_" href="#_68">ཕྱིན</a></dfn>་<dfn class="na" title="['collect; conclude; gather; include; abridge']"><a id="69_" href="#_69">བསྡུས</a></dfn>་པ་<dfn class="na" title="['после', 'затем', 'деепричастие …ев/ув', 'среди различных', 'сравнит чем', 'action; deed; work; having (done something)']"><a id="5_" href="#_5">ལས</a></dfn>།</div> <div class="cite">།<dfn class="na" title="['to disintegrate; disintegrate; destroy']"><a id="70_" href="#_70">འཇིག</a></dfn>་རྟེན་<dfn class="na" title="['nn', 'Цель']"><a id="63_" href="#_63">དོན</a></dfn>་<dfn class="na" title="['achieve; attain; accomplish; prove; complete; practice']"><a id="71_" href="#_71">སྒྲུབ</a></dfn>་ཚུལ་<dfn class="cc" title="['cc', ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки', 'идти']]"><a id="16_" href="#_16">ལ</a></dfn>་མཐུ་<dfn class="na" title="['после་ отрицаемого', 'not exist; not be', 'not to have']"><a id="72_" href="#_72">མེད</a></dfn>་པའི། །<dfn class="na" title="['vehicle']"><a id="6_" href="#_6">ཐེག</a></dfn>་པ་<dfn class="na" title="['two']"><a id="73_" href="#_73">གཉིས</a></dfn>་པོ་གཏན་<dfn class="cc" title="['cc', ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки']]"><a id="37_" href="#_37">དུ</a></dfn>་<dfn class="na" title="['abandon; give up; eliminate; dispel; dispell; set aside']"><a id="74_" href="#_74">སྤང</a></dfn>་<dfn class="na" title="['vb, do; act; perform; fabricate; take ... as; noun: action; activity; performance {C}produced; conditioned; compounded; effected (fut.t.)']"><a id="75_" href="#_75">བྱས</a></dfn>་ཤིང༌། །ཐུབ་<dfn class="na" title="['conquest; victory']"><a id="13_" href="#_13">རྒྱལ</a></dfn>་<dfn class="na" title="['vehicle']"><a id="6_" href="#_6">ཐེག</a></dfn>་པ་སྙིང་<dfn class="na" title="['after; subsequent to']"><a id="76_" href="#_76">རྗེས</a></dfn>་<dfn class="na" title="['to show (past/present/future honorific)']"><a id="18_" href="#_18">བསྟན</a></dfn>་པ་<dfn class="cc" title="['cc', ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки', 'идти']]"><a id="16_" href="#_16">ལ</a></dfn>། །གཞན་<dfn class="na" title="['help; benefit; be of use']"><a id="77_" href="#_77">ཕན</a></dfn>་རོ་<dfn class="na" title="['same, one; oneness; distinguished by; unitary']"><a id="78_" href="#_78">གཅིག</a></dfn>་རང་<dfn class="na" title="['-ing']"><a id="79_" href="#_79">བཞིན</a></dfn>་<dfn class="cc" title="['cc', 'потому что', 'значит', '.. это так', 'потому что..', '.. - это ..', '.. - то что..']"><a id="31_" href="#_31">དེ</a></dfn>་<dfn class="na" title="['1) to purify; to clean; 2) plural marker']"><a id="80_" href="#_80">དག</a></dfn>་<dfn class="na" title="['enter; engage; apply; usher (into); engages']"><a id="7_" href="#_7">འཇུག</a></dfn></div> <br>
# །<dfn class="na" title="['.. - это..']"><a id="81_" href="#_81">ཅེས</a></dfn>་དང༌།<br>
# <div class="cite">།བདེ་<dfn class="cc" title="['cc', 'собирание и разделение', 'по причине', '..непосредственно после', 'наставление/указание']"><a id="12_" href="#_12">དང</a></dfn>་མི་བདེ་རྨི་<dfn class="na" title="['..или.', '.?', '.,', 'path; way; road; [connective particle:] and; or']"><a id="3_" href="#_3">ལམ</a></dfn>་འདྲར་<dfn class="na" title="['count; number; calculate; compute; reckon; enumerate; tally; numerate']"><a id="82_" href="#_82">བགྲངས</a></dfn>་ཤིང༌། །གཏི་མུག་སྐྱོན་<dfn class="cc" title="['cc', 'деятель', 'инструмент', 'c отношением', 'По причине', 'из-за', 'вследствии', '(semi-colon); (as imperative verb form) do']"><a id="83_" href="#_83">གྱིས</a></dfn>་དམའ་བའི་<dfn class="na" title="['vb, go; (pres) become; serve; act; noun: transmigrator; goer']"><a id="84_" href="#_84">འགྲོ</a></dfn>་<dfn class="na" title="['to see; to perceive (present/passive)']"><a id="40_" href="#_40">མཐོང</a></dfn>་<dfn class="cc" title="['cc', ['если'], ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки'], ['be sick; be ill; in pain for the verb', 'na ba']]"><a id="53_" href="#_53">ན</a></dfn>། །<dfn class="na" title="['после', 'затем', 'деепричастие …ев/ув', 'среди различных', 'сравнит чем', 'action; deed; work; having (done something)']"><a id="5_" href="#_5">ལས</a></dfn>་<dfn class="cc" title="['cc', 'владение/принадлежность', 'соответствующее основе качество', 'место объекта', 'часть из/среди целого']"><a id="14_" href="#_14">ཀྱི</a></dfn>་<dfn class="na" title="['..или..', '..?', '..,']"><a id="27_" href="#_27">དམ</a></dfn>་པ་གཞན་<dfn class="na" title="['nn', 'Цель']"><a id="63_" href="#_63">དོན</a></dfn>་<dfn class="na" title="['joy; happiness; liking']"><a id="85_" href="#_85">དགའ</a></dfn>་<dfn class="na" title="['to throw away; to give up or cast aside']"><a id="86_" href="#_86">བོར</a></dfn>་ཞིང༌། །རང་<dfn class="cc" title="['cc', 'владение/принадлежность', 'соответствующее основе качество', 'место объекта', 'часть из/среди целого']"><a id="62_" href="#_62">གི</a></dfn>་<dfn class="na" title="['nn', 'Цель']"><a id="63_" href="#_63">དོན</a></dfn>་<dfn class="cc" title="['cc', ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки', 'идти']]"><a id="16_" href="#_16">ལ</a></dfn>་<dfn class="cc" title="['cc', 'потому что', 'значит', '.. это так', 'потому что..', '.. - это ..', '.. - то что..']"><a id="31_" href="#_31">དེ</a></dfn>་ཀོ་<dfn class="na" title="['в случае/но если...?']"><a id="87_" href="#_87">ཅི་སྟེ</a></dfn>་<dfn class="na" title="['vb, to endeavor; make effort; strive; exert oneself; noun: effort; endeavor; exertion']"><a id="88_" href="#_88">བརྩོན</a></dfn>།</div> <br>
# །<dfn class="na" title="['.. - это..']"><a id="89_" href="#_89">ཞེས</a></dfn>་<dfn class="na" title="['said; mentioned; say; talk H']"><a id="90_" href="#_90">གསུངས</a></dfn>་པ་<dfn class="na" title="['ābha', 'like; thus; in accordance with']"><a id="32_" href="#_32">ལྟར</a></dfn>་རོ།<br>
#   །<dfn class="cc" title="['cc', 'потому что', 'значит', '.. это так', 'потому что..', '.. - это ..', '.. - то что..']"><a id="31_" href="#_31">དེ</a></dfn>་<dfn class="na" title="['ābha', 'like; thus; in accordance with']"><a id="32_" href="#_32">ལྟར</a></dfn>་རང་ཉིད་སྲིད་པའི་མཚོར་ལྷུང་བ་<dfn class="cc" title="['cc', 'собирание и разделение', 'по причине', '..непосредственно после', 'наставление/указание']"><a id="12_" href="#_12">དང</a></dfn>་<dfn class="na" title="['similar; same; similarity; likeness; like; similar; image']"><a id="91_" href="#_91">འདྲ</a></dfn>་བར་<dfn class="na" title="['vb, go; (pres) become; serve; act; noun: transmigrator; goer']"><a id="84_" href="#_84">འགྲོ</a></dfn>་བ་རྣམས་<dfn class="na" title="['и .. тоже', 'действительно', 'слишком', 'хотя..', 'но..', 'даже..', 'тоже', 'также..']"><a id="59_" href="#_59">ཀྱང</a></dfn>་<dfn class="na" title="['adopt; adopting; assume; take up; take; receive; assert; assertion']"><a id="92_" href="#_92">བླང</a></dfn>་<dfn class="na" title="['discard; reject; cast out; forsake; cancel']"><a id="93_" href="#_93">དོར</a></dfn>་<dfn class="na" title="['to separate; open; separate; differentiate{BJ}; opener{BR}']"><a id="94_" href="#_94">འབྱེད</a></dfn>་པའི་<dfn class="na" title="['nn', 'prajñā', 'проникающее-различающее Знание']"><a id="95_" href="#_95">ཤེས་རབ</a></dfn>་<dfn class="cc" title="['cc', 'владение/принадлежность', 'соответствующее основе качество', 'место объекта', 'часть из/среди целого']"><a id="14_" href="#_14">ཀྱི</a></dfn>་མིག་ཟུམ་<dfn class="na" title="['и так', '1.инструмент частица', '2.(vb. +--) потому что 3.(vb. +--) вопрос 4.в соответствии с', 'поскольку', 'когда']"><a id="29_" href="#_29">པས</a></dfn>་ཉམ་<dfn class="na" title="['я', "adj'ng + nga = comparative"]"><a id="96_" href="#_96">ང</a></dfn>་བ་<dfn class="cc" title="['cc', 'собирание и разделение', 'по причине', '..непосредственно после', 'наставление/указание']"><a id="12_" href="#_12">དང</a></dfn>་<dfn class="na" title="['separation; free from; lack; devoid; separate from']"><a id="97_" href="#_97">བྲལ</a></dfn>་བའི་ཕྱོགས་<dfn class="na" title="['кто']"><a id="98_" href="#_98">སུ</a></dfn>་<dfn class="na" title="['progress; get along; advance; proceed; travel; go; traverse; vehicle']"><a id="99_" href="#_99">བགྲོད</a></dfn>་མི་<dfn class="na" title="['ability; able; potency; power; capacity']"><a id="100_" href="#_100">ནུས</a></dfn>་པར་གོམ་འགྲོས་འཁྱོར་བ་<dfn class="na" title="['to see; to perceive (present/passive)']"><a id="40_" href="#_40">མཐོང</a></dfn>་<dfn class="cc" title="['cc', ['если'], ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки'], ['be sick; be ill; in pain for the verb', 'na ba']]"><a id="53_" href="#_53">ན</a></dfn>། <dfn class="na" title="['conquest; victory']"><a id="13_" href="#_13">རྒྱལ</a></dfn>་བའི་རིགས་<dfn class="cc" title="['cc', 'собирание и разделение', 'по причине', '..непосредственно после', 'наставление/указание']"><a id="12_" href="#_12">དང</a></dfn>་<dfn class="na" title="['обладающий', 'наделенный']"><a id="28_" href="#_28">ལྡན</a></dfn>་པ་རྣམས་གཞན་<dfn class="cc" title="['cc', ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки', 'идти']]"><a id="16_" href="#_16">ལ</a></dfn>་<dfn class="na" title="['noun: mercy; love; kindness; vb, feel mercy; pity; love']"><a id="101_" href="#_101">བརྩེ</a></dfn>་བ་<dfn class="na" title="['после་ отрицаемого', 'not exist; not be', 'not to have']"><a id="72_" href="#_72">མེད</a></dfn>་པ་<dfn class="cc" title="['cc', 'собирание и разделение', 'по причине', '..непосредственно посл ...
# <br><div class="cite_src">།<dfn class="cc" title="['cc', 'потому что', 'значит', '.. это так', 'потому что..', '.. - это ..', '.. - то что..']"><a id="31_" href="#_31">དེ</a></dfn>་ཉིད་<dfn class="na" title="['после', 'затем', 'деепричастие …ев/ув', 'среди различных', 'сравнит чем', 'action; deed; work; having (done something)']"><a id="5_" href="#_5">ལས</a></dfn>།</div> <div class="cite">།<dfn class="na" title="['nn', 'prajñā', 'проникающее-различающее Знание']"><a id="95_" href="#_95">ཤེས་རབ</a></dfn>་མིག་ཟུམ་འགྲོས་འཁྱོར་<dfn class="na" title="['become; change; transform; arise; be']"><a id="102_" href="#_102">གྱུར</a></dfn>་པ་<dfn class="cc" title="['cc', ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки', 'идти']]"><a id="16_" href="#_16">ལ</a></dfn>། །<dfn class="na" title="['to disintegrate; disintegrate; destroy']"><a id="70_" href="#_70">འཇིག</a></dfn>་རྟེན་<dfn class="na" title="['nn', 'Цель']"><a id="63_" href="#_63">དོན</a></dfn>་<dfn class="na" title="['achieve; attain; accomplish; prove; complete; practice']"><a id="71_" href="#_71">སྒྲུབ</a></dfn>་<dfn class="na" title="['conquest; victory']"><a id="13_" href="#_13">རྒྱལ</a></dfn>་བའི་<dfn class="na" title="['conquest; victory']"><a id="13_" href="#_13">རྒྱལ</a></dfn>་རིགས་<dfn class="cc" title="['cc', ['если'], ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки'], ['be sick; be ill; in pain for the verb', 'na ba']]"><a id="53_" href="#_53">ན</a></dfn>། །<dfn class="na" title="['pretty, nice, beautiful, compassion, kindness, mercy, pity']"><a id="103_" href="#_103">སྙིང་རྗེ</a></dfn>་མི་<dfn class="na" title="['generate; produce; engender']"><a id="8_" href="#_8">བསྐྱེད</a></dfn>་<dfn class="na" title="['be born; be produced; be engendered']"><a id="1_" href="#_1">སྐྱེས</a></dfn>་བུ་<dfn class="na" title="['чего/какой бы', 'который', 'что', 'куда']"><a id="104_" href="#_104">གང</a></dfn>་<dfn class="na" title="['побуждение', 'призыв - .!', 'кто-либо', 'destroy-past tns', 'второй слог']"><a id="105_" href="#_105">ཞིག</a></dfn>་<dfn class="na" title="['be', 'live', 'exist', 'have', 'there is', 'has', 'have', 'was', 'matter', 'who were present']"><a id="106_" href="#_106">ཡོད</a></dfn>། །<dfn class="cc" title="['cc', 'потому что', 'значит', '.. это так', 'потому что..', '.. - это ..', '.. - то что..']"><a id="31_" href="#_31">དེ</a></dfn>་<dfn class="na" title="['1) to purify; to clean; 2) plural marker']"><a id="80_" href="#_80">དག</a></dfn>་<dfn class="na" title="['obscuration; delusion; confusion; ignorance; dullness']"><a id="107_" href="#_107">རྨོངས</a></dfn>་<dfn class="na" title="['clear away; remove; throw off; eradicate; separate']"><a id="108_" href="#_108">བསལ</a></dfn>་<dfn class="na" title="['vb, to endeavor; make effort; strive; exert oneself; noun: effort; endeavor; exertion']"><a id="88_" href="#_88">བརྩོན</a></dfn>་<dfn class="na" title="['zeal; enthusiasm; diligence']"><a id="109_" href="#_109">འགྲུས</a></dfn>་<dfn class="na" title="['кто']"><a id="98_" href="#_98">སུ</a></dfn>་མི་<dfn class="na" title="['begin; initiate; compose; write a book']"><a id="110_" href="#_110">རྩོམ</a></dfn>།</div> <br>
# །<dfn class="na" title="['.. - это..']"><a id="89_" href="#_89">ཞེས</a></dfn>་སོ།<br>
#   །<dfn class="na" title="['это']"><a id="111_" href="#_111">འདི</a></dfn>་<dfn class="cc" title="['cc', ['если'], ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки'], ['be sick; be ill; in pain for the verb', 'na ba']]"><a id="53_" href="#_53">ན</a></dfn>་<dfn class="na" title="['be born; be produced; be engendered']"><a id="1_" href="#_1">སྐྱེས</a></dfn>་བུ་རྣམས་<dfn class="cc" title="['cc', 'владение/принадлежность', 'соответствующее основе качество', 'место объекта', 'часть из/среди целого']"><a id="14_" href="#_14">ཀྱི</a></dfn>་བདེ་བ་<dfn class="cc" title="['cc', 'собирание и разделение', 'по причине', '..непосредственно после', 'наставление/указание']"><a id="12_" href="#_12">དང</a></dfn>་<dfn class="na" title="['shine; glitter']"><a id="112_" href="#_112">བརྗིད</a></dfn>་བག་<dfn class="cc" title="['cc', 'собирание и разделение', 'по причине', '..непосредственно после', 'наставление/указание']"><a id="12_" href="#_12">དང</a></dfn>་<dfn class="na" title="['be born; be produced; be engendered']"><a id="1_" href="#_1">སྐྱེས</a></dfn>་བུའི་<dfn class="na" title="['capacity; manifest capacity; dexterity; power']"><a id="113_" href="#_113">རྩལ</a></dfn>་<dfn class="na" title="['..-', '..касаемо']"><a id="23_" href="#_23">ནི</a></dfn>་གཞན་<dfn class="cc" title="['cc', 'владение/принадлежность', 'соответствующее основе качество', 'место объекта', 'часть из/среди целого']"><a id="4_" href="#_4">གྱི</a></dfn>་<dfn class="na" title="['nn', 'Цель']"><a id="63_" href="#_63">དོན</a></dfn>་<dfn class="na" title="['burden; load']"><a id="114_" href="#_114">ཁུར</a></dfn>་<dfn class="cc" title="['cc', ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки']]"><a id="37_" href="#_37">དུ</a></dfn>་<dfn class="na" title="['to carry; bear; bring']"><a id="115_" href="#_115">འཁྱེར</a></dfn>་བ་<dfn class="cc" title="['cc', ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки', 'идти']]"><a id="16_" href="#_16">ལ</a></dfn>་<dfn class="na" title="['1. activity; object; deed; do; action to do; make; perform 2. bird (pas.t.)']"><a id="116_" href="#_116">བྱ</a></dfn>་བར་རིགས་<dfn class="cc" title="['cc', 'потому что', 'значит', '.. это так', 'потому что..', '.. - это ..', '.. - то что..']"><a id="67_" href="#_67">ཏེ</a></dfn>། རང་<dfn class="cc" title="['cc', 'владение/принадлежность', 'соответствующее основе качество', 'место объекта', 'часть из/среди целого']"><a id="62_" href="#_62">གི</a></dfn>་<dfn class="na" title="['nn', 'Цель']"><a id="63_" href="#_63">དོན</a></dfn>་<dfn class="na" title="['approximately, roughly']"><a id="117_" href="#_117">ཙམ</a></dfn>་<dfn class="cc" title="['cc', ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки', 'идти']]"><a id="16_" href="#_16">ལ</a></dfn>་<dfn class="na" title="['to observe{D2}; apprehend; be aware of; object of observation (=dmigs pa)']"><a id="34_" href="#_34">དམིགས</a></dfn>་པ་<dfn class="na" title="['..-', '..касаемо']"><a id="23_" href="#_23">ནི</a></dfn>་དུད་<dfn class="na" title="['vb, go; (pres) become; serve; act; noun: transmigrator; goer']"><a id="84_" href="#_84">འགྲོ</a></dfn>་རྣམས་<dfn class="cc" title="['cc', 'соб ...
#
# དེའི་ཕྱིར་<dfn class="na" title="['big (size), great']"><a id="2_" href="#_2">ཆེན</a></dfn>་པོ་རྣམས་<dfn class="cc" title="['cc', 'владение/принадлежность', 'соответствующее основе качество', 'место объекта', 'часть из/среди целого']"><a id="14_" href="#_14">ཀྱི</a></dfn>་ངང་ཚུལ་<dfn class="na" title="['..-', '..касаемо']"><a id="23_" href="#_23">ནི</a></dfn>་གཞན་<dfn class="cc" title="['cc', 'владение/принадлежность', 'соответствующее основе качество', 'место объекта', 'часть из/среди целого']"><a id="4_" href="#_4">གྱི</a></dfn>་<dfn class="na" title="['help; benefit; be of use']"><a id="77_" href="#_77">ཕན</a></dfn>་བདེ་<dfn class="cc" title="['cc', ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки', 'идти']]"><a id="16_" href="#_16">ལ</a></dfn>་མཐའ་<dfn class="na" title="['same, one; oneness; distinguished by; unitary']"><a id="78_" href="#_78">གཅིག</a></dfn>་<dfn class="cc" title="['cc', ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки']]"><a id="48_" href="#_48">ཏུ</a></dfn>་<dfn class="na" title="['to flow {T}']"><a id="118_" href="#_118">གཞོལ</a></dfn>་བ་ཡིན་<dfn class="cc" title="['cc', 'потому что', 'значит', '.. это так', 'потому что..', '.. - это ..', '.. - то что..']"><a id="67_" href="#_67">ཏེ</a></dfn>།
# <br><div class="cite_src">།<dfn class="na" title="['to learn; teach; train in']"><a id="24_" href="#_24">སློབ</a></dfn>་མ་<dfn class="cc" title="['cc', ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки', 'идти']]"><a id="16_" href="#_16">ལ</a></dfn>་སྤྲིངས་པ་<dfn class="na" title="['после', 'затем', 'деепричастие …ев/ув', 'среди различных', 'сравнит чем', 'action; deed; work; having (done something)']"><a id="5_" href="#_5">ལས</a></dfn>།</div> <div class="cite">།ཤིན་<dfn class="cc" title="['cc', ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки']]"><a id="48_" href="#_48">ཏུ</a></dfn>་<dfn class="na" title="['vb, find; gain; discover; noun: goods; property; profit']"><a id="119_" href="#_119">རྙེད</a></dfn>་སླའི་རྩྭ་ཁམ་འགའ་<dfn class="na" title="['vb, view; look (pres); see; read noun: view; false view']"><a id="120_" href="#_120">ལྟ</a></dfn>་ཕྱུགས་<dfn class="na" title="['и .. тоже', 'действительно', 'слишком', 'хотя..', 'но..', 'даже..', 'тоже', 'также..']"><a id="59_" href="#_59">ཀྱང</a></dfn>་རང་ཉིད་<dfn class="na" title="['food; to eat (present nh.)']"><a id="121_" href="#_121">ཟ</a></dfn>། །ཤིན་<dfn class="cc" title="['cc', ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки']]"><a id="48_" href="#_48">ཏུ</a></dfn>་<dfn class="na" title="['to feel thirsty']"><a id="122_" href="#_122">སྐོམ</a></dfn>་<dfn class="na" title="['и так', '1.инструмент частица', '2.(vb. +--) потому что 3.(vb. +--) вопрос 4.в соответствии с', 'поскольку', 'когда']"><a id="29_" href="#_29">པས</a></dfn>་<dfn class="na" title="['torment; be tormented; be scorched; desire; long for']"><a id="49_" href="#_49">གདུངས</a></dfn>་པའང་ཆུ་<dfn class="na" title="['побуждение', 'призыв - .!', 'кто-либо', 'destroy-past tns', 'второй слог']"><a id="105_" href="#_105">ཞིག</a></dfn>་<dfn class="na" title="['vb, find; gain; discover; noun: goods; property; profit']"><a id="119_" href="#_119">རྙེད</a></dfn>་<dfn class="cc" title="['cc', ['если'], ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки'], ['be sick; be ill; in pain for the verb', 'na ba']]"><a id="53_" href="#_53">ན</a></dfn>་<dfn class="na" title="['joy; happiness; liking']"><a id="85_" href="#_85">དགའ</a></dfn>་མགུར་འཐུང༌། །<dfn class="na" title="['это']"><a id="111_" href="#_111">འདི</a></dfn>་<dfn class="cc" title="['cc', ['если'], ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки'], ['be sick; be ill; in pain for the verb', 'na ba']]"><a id="53_" href="#_53">ན</a></dfn>་<dfn class="na" title="['be born; be produced; be engendered']"><a id="1_" href="#_1">སྐྱེས</a></dfn>་བུ་གཞན་<dfn class="na" title="['nn', 'Цель']"><a id="63_" href="#_63">དོན</a></dfn>་<dfn class="na" title="['do; act; perform; does; refer (to), to happen (pres.t.)']"><a id="123_" href="#_123">བྱེད</a></dfn>་པར་<dfn class="na" title="['vb, to endeavor; make effort; strive; exert oneself; noun: effort; endeavor; exertion']"><a id="88_" hr ...
# །<dfn class="na" title="['.. - это..']"><a id="89_" href="#_89">ཞེས</a></dfn>་སོ།<br>
#   །<dfn class="cc" title="['cc', 'потому что', 'значит', '.. это так', 'потому что..', '.. - это ..', '.. - то что..']"><a id="31_" href="#_31">དེ</a></dfn>་<dfn class="na" title="['ābha', 'like; thus; in accordance with']"><a id="32_" href="#_32">ལྟར</a></dfn>་<dfn class="na" title="['vb, go; (pres) become; serve; act; noun: transmigrator; goer']"><a id="84_" href="#_84">འགྲོ</a></dfn>་བ་<dfn class="na" title="['dear; kind; beloved']"><a id="43_" href="#_43">སྡུག</a></dfn>་བསྔལ་<dfn class="cc" title="['cc', 'деятель', 'инструмент', 'c отношением', 'По причине', 'из-за', 'вследствии', '(semi-colon); (as imperative verb form) do']"><a id="83_" href="#_83">གྱིས</a></dfn>་ཀུན་<dfn class="cc" title="['cc', ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки']]"><a id="48_" href="#_48">ཏུ</a></dfn>་<dfn class="na" title="['torment; be tormented; be scorched; desire; long for']"><a id="49_" href="#_49">གདུངས</a></dfn>་པར་<dfn class="na" title="['to see; to perceive (present/passive)']"><a id="40_" href="#_40">མཐོང</a></dfn>་<dfn class="na" title="['после', 'затем', 'деепричастие …ев/ув', 'среди подобных', 'от .. и до..']"><a id="19_" href="#_19">ནས</a></dfn>་<dfn class="cc" title="['cc', 'потому что', 'значит', '.. это так', 'потому что..', '.. - это ..', '.. - то что..']"><a id="31_" href="#_31">དེ</a></dfn>་<dfn class="na" title="['1) to purify; to clean; 2) plural marker']"><a id="80_" href="#_80">དག</a></dfn>་<dfn class="cc" title="['cc', 'владение/принадлежность', 'соответствующее основе качество', 'место объекта', 'часть из/среди целого']"><a id="62_" href="#_62">གི</a></dfn>་<dfn class="na" title="['nn', 'Цель']"><a id="63_" href="#_63">དོན</a></dfn>་<dfn class="cc" title="['cc', ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки']]"><a id="37_" href="#_37">དུ</a></dfn>་བྲེལ་བ་<dfn class="cc" title="['cc', ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки', 'идти']]"><a id="16_" href="#_16">ལ</a></dfn>་<dfn class="na" title="['be born; be produced; be engendered']"><a id="1_" href="#_1">སྐྱེས</a></dfn>་བུ་<dfn class="na" title="['.. - это..']"><a id="89_" href="#_89">ཞེས</a></dfn>་<dfn class="na" title="['1. activity; object; deed; do; action to do; make; perform 2. bird (pas.t.)']"><a id="116_" href="#_116">བྱ</a></dfn>་<dfn class="cc" title="['cc', ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки', 'идти']]"><a id="16_" href="#_16">ལ</a></dfn>་<dfn class="na" title="['wise; skilled; be skillful; scholar']"><a id="129_" href="#_129">མཁས</a></dfn>་པ་<dfn class="na" title="['.. - это..']"><a id="89_" href="#_89">ཞེས</a></dfn>་<dfn class="na" title="['и .. тоже', 'действительно', 'слишком', 'хотя..', 'но..', 'даже..', 'тоже', 'также..']"><a id="59_" href="#_59">ཀྱང</a></dfn>་<dfn class="cc" title="['cc', 'потому что', 'значит', '.. это так', 'потому что..', '.. - это ..', '.. - то что..']"><a id="31_" href="#_31">དེ</a></dfn>་<dfn class="cc" title="['cc', ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно',  ...
# <p id="_1">1 <a lang="bo">སྐྱེས</a> = ['be born; be produced; be engendered']</p>
# <p id="_2">2 <a lang="bo">ཆེན</a> = ['big (size), great']</p>
# <p id="_3">3 <a lang="bo">ལམ</a> = ['..или.', '.?', '.,', 'path; way; road; [connective particle:] and; or']</p>
# <p id="_4">4 <a lang="bo">གྱི</a> = ['cc', 'владение/принадлежность', 'соответствующее основе качество', 'место объекта', 'часть из/среди целого']</p>
# <p id="_5">5 <a lang="bo">ལས</a> = ['после', 'затем', 'деепричастие …ев/ув', 'среди различных', 'сравнит чем', 'action; deed; work; having (done something)']</p>
# <p id="_6">6 <a lang="bo">ཐེག</a> = ['vehicle']</p>
# <p id="_7">7 <a lang="bo">འཇུག</a> = ['enter; engage; apply; usher (into); engages']</p>
# <p id="_8">8 <a lang="bo">བསྐྱེད</a> = ['generate; produce; engender']</p>
# <p id="_9">9 <a lang="bo">བཞུགས་སོ</a> = ['так называется']</p>
# <p id="_10">10 <a lang="bo">སྨོན</a> = ['wish; admire; pray; aspire']</p>
# <p id="_11">11 <a lang="bo">སྦྱང</a> = ['to learn (present nh.), purify; wash; practice; train; clean;']</p>
# <p id="_12">12 <a lang="bo">དང</a> = ['cc', 'собирание и разделение', 'по причине', '..непосредственно после', 'наставление/указание']</p>
# <p id="_13">13 <a lang="bo">རྒྱལ</a> = ['conquest; victory']</p>
# <p id="_14">14 <a lang="bo">ཀྱི</a> = ['cc', 'владение/принадлежность', 'соответствующее основе качество', 'место объекта', 'часть из/среди целого']</p>
# <p id="_15">15 <a lang="bo">སྤྱོད</a> = ['enjoy; make use of; practice; act out; perform; behavior; deeds; performance']</p>
# <p id="_16">16 <a lang="bo">ལ</a> = ['cc', ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки', 'идти']]</p>
# <p id="_17">17 <a lang="bo">བསླབ</a> = ['to learn; teach; train in (present, past nh.)']</p>
# <p id="_18">18 <a lang="bo">བསྟན</a> = ['to show (past/present/future honorific)']</p>
# <p id="_19">19 <a lang="bo">ནས</a> = ['после', 'затем', 'деепричастие …ев/ув', 'среди подобных', 'от .. и до..']</p>
# <p id="_20">20 <a lang="bo">བདུན</a> = ['seven']</p>
# <p id="_21">21 <a lang="bo">ཞི</a> = ['be peaceful; be calm; peace; pacification']</p>
# <p id="_22">22 <a lang="bo">བརྟེན</a> = ['depend upon; rely; resort to; support']</p>
# <p id="_23">23 <a lang="bo">ནི</a> = ['..-', '..касаемо']</p>
# <p id="_24">24 <a lang="bo">སློབ</a> = ['to learn; teach; train in']</p>
# <p id="_25">25 <a lang="bo">ངེས</a> = ['ascertain; ascertainment; certain']</p>
# <p id="_26">26 <a lang="bo">རྗེ</a> = ['master; lord; leaders']</p>
# <p id="_27">27 <a lang="bo">དམ</a> = ['..или..', '..?', '..,']</p>
# <p id="_28">28 <a lang="bo">ལྡན</a> = ['обладающий', 'наделенный']</p>
# <p id="_29">29 <a lang="bo">པས</a> = ['и так', '1.инструмент частица', '2.(vb. +--) потому что 3.(vb. +--) вопрос 4.в соответствии с', 'поскольку', 'когда']</p>
# <p id="_30">30 <a lang="bo">འཚལ</a> = ['seek; want; ask; beg; beseech; desire; ; to understand']</p>
# <p id="_31">31 <a lang="bo">དེ</a> = ['cc', 'потому что', 'значит', '.. это так', 'потому что..', '.. - это ..', '.. - то что..']</p>
# <p id="_32">32 <a lang="bo">ལྟར</a> = ['ābha', 'like; thus; in accordance with']</p>
# <p id="_33">33 <a lang="bo">ཉེས</a> = ['bad; sin; evil; crime']</p>
# <p id="_34">34 <a lang="bo">དམིགས</a> = ['to observe{D2}; apprehend; be aware of; object of observation (=dmigs pa)']</p>
# <p id="_35">35 <a lang="bo">སྣ་ཚོགས</a> = ['varied, of different kinds, diversity']</p>
# <p id="_36">36 <a lang="bo">རིང</a> = ['long time, tall, long, lengthwise']</p>
# <p id="_37">37 <a lang="bo">དུ</a> = ['cc', ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки']]</p>
# <p id="_38">38 <a lang="bo">བསྒོམས</a> = ['meditate; meditatively cultivate']</p>
# <p id="_39">39 <a lang="bo">འབར</a> = ['burn; blaze up; blaze; catch fire; flaming; fire']</p>
# <p id="_40">40 <a lang="bo">མཐོང</a> = ['to see; to perceive (present/passive)']</p>
# <p id="_41">41 <a lang="bo">སྟེ</a> = ['cc', 'after--', 'having--', 'adverbal; потому что', 'значит', '.. это так', 'потому что..', '.. - это ..', '.. - то что..']</p>
# <p id="_42">42 <a lang="bo">ཉོན</a> = ['affliction']</p>
# <p id="_43">43 <a lang="bo">སྡུག</a> = ['dear; kind; beloved']</p>
# <p id="_44">44 <a lang="bo">ཉེ</a> = ['near; dear; intimate']</p>
# <p id="_45">45 <a lang="bo">ཐོབ</a> = ['attain; obtain; get, to win']</p>
# <p id="_46">46 <a lang="bo">འདོད</a> = ['accept; assert; wish; desire; consider; to want (used with other verbs)']</p>
# <p id="_47">47 <a lang="bo">ཀྱིས</a> = ['cc', 'деятель', 'инструмент', 'c отношением', 'По причине', 'из-за', 'вследствии']</p>
# <p id="_48">48 <a lang="bo">ཏུ</a> = ['cc', ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки']]</p>
# <p id="_49">49 <a lang="bo">གདུངས</a> = ['torment; be tormented; be scorched; desire; long for']</p>
# <p id="_50">50 <a lang="bo">ཆེ</a> = ['great, large, big, senior, elder']</p>
# <p id="_51">51 <a lang="bo">གསུམ</a> = ['three']</p>
# <p id="_52">52 <a lang="bo">བསླབས</a> = ['to learn; teach; train in (present, past nh.)']</p>
# <p id="_53">53 <a lang="bo">ན</a> = ['cc', ['если'], ['по направлению/месту', 'отсутствие заявленной цели', 'adj+ly'], ['Предоставление чего-либо', 'кому-либо', 'для', 'что-бы'], ['взаиморасположение и местопребывание', 'без движения', 'относительно', 'касательно', 'в обстоятельствах', 'место', 'время', 'среди..', 'заголовки'], ['be sick; be ill; in pain for the verb', 'na ba']]</p>
# <p id="_54">54 <a lang="bo">གྲོལ</a> = ['released; loosened; freed']</p>
# <p id="_55">55 <a lang="bo">འཐོབ</a> = ['get; attain; will get; will attain [future of thob]']</p>
# <p id="_56">56 <a lang="bo">ཡང</a> = [['и .. тоже', 'действительно', 'слишком', 'хотя..', 'но..', 'даже..', 'тоже', 'также..'], ['дополнения строф']]</p>
# <p id="_57">57 <a lang="bo">མཐོ</a> = ['high; elevated, prominent; superior']</p>
# <p id="_58">58 <a lang="bo">ལྡོག</a> = ['reverse; cease; turn around; isolate; eliminate; reversed']</p>
# <p id="_59">59 <a lang="bo">ཀྱང</a> = ['и .. тоже', 'действительно', 'слишком', 'хотя..', 'но..', 'даже..', 'тоже', 'также..']</p>
# <p id="_60">60 <a lang="bo">ཟད</a> = ['use up; exhaust; consume; subsume; extinction; removal; exhaustion; used up; exhausted; extinct; extinguished; consumed; subsumed; ; [with negative:] not only; inexhaustible']</p>
# <p id="_61">61 <a lang="bo">རེ</a> = ['each; every; single; hope']</p>
# <p id="_62">62 <a lang="bo">གི</a> = ['cc', 'владение/принадлежность', 'соответствующее основе качество', 'место объекта', 'часть из/среди целого']</p>
# <p id="_63">63 <a lang="bo">དོན</a> = ['nn', 'Цель']</p>
# <p id="_64">64 <a lang="bo">རྫོགས</a> = ['complete; end; finish; perfect; fulfill; terminate']</p>
# <p id="_65">65 <a lang="bo">སངས་རྒྱས</a> = ['nn', 'Будда']</p>
# <p id="_66">66 <a lang="bo">བསྐུལ</a> = ['rouse; arouse; entreat; urge on; incite; urge; exhort']</p>
# <p id="_67">67 <a lang="bo">ཏེ</a> = ['cc', 'потому что', 'значит', '.. это так', 'потому что..', '.. - это ..', '.. - то что..']</p>
# <p id="_68">68 <a lang="bo">ཕྱིན</a> = ["went [past of 'gro, 'to go']"]</p>
# <p id="_69">69 <a lang="bo">བསྡུས</a> = ['collect; conclude; gather; include; abridge']</p>
# <p id="_70">70 <a lang="bo">འཇིག</a> = ['to disintegrate; disintegrate; destroy']</p>
# <p id="_71">71 <a lang="bo">སྒྲུབ</a> = ['achieve; attain; accomplish; prove; complete; practice']</p>
# <p id="_72">72 <a lang="bo">མེད</a> = ['после་ отрицаемого', 'not exist; not be', 'not to have']</p>
# <p id="_73">73 <a lang="bo">གཉིས</a> = ['two']</p>
# <p id="_74">74 <a lang="bo">སྤང</a> = ['abandon; give up; eliminate; dispel; dispell; set aside']</p>
# <p id="_75">75 <a lang="bo">བྱས</a> = ['vb, do; act; perform; fabricate; take ... as; noun: action; activity; performance {C}produced; conditioned; compounded; effected (fut.t.)']</p>
# <p id="_76">76 <a lang="bo">རྗེས</a> = ['after; subsequent to']</p>
# <p id="_77">77 <a lang="bo">ཕན</a> = ['help; benefit; be of use']</p>
# <p id="_78">78 <a lang="bo">གཅིག</a> = ['same, one; oneness; distinguished by; unitary']</p>
# <p id="_79">79 <a lang="bo">བཞིན</a> = ['-ing']</p>
# <p id="_80">80 <a lang="bo">དག</a> = ['1) to purify; to clean; 2) plural marker']</p>
# <p id="_81">81 <a lang="bo">ཅེས</a> = ['.. - это..']</p>
# <p id="_82">82 <a lang="bo">བགྲངས</a> = ['count; number; calculate; compute; reckon; enumerate; tally; numerate']</p>
# <p id="_83">83 <a lang="bo">གྱིས</a> = ['cc', 'деятель', 'инструмент', 'c отношением', 'По причине', 'из-за', 'вследствии', '(semi-colon); (as imperative verb form) do']</p>
# <p id="_84">84 <a lang="bo">འགྲོ</a> = ['vb, go; (pres) become; serve; act; noun: transmigrator; goer']</p>
# <p id="_85">85 <a lang="bo">དགའ</a> = ['joy; happiness; liking']</p>
# <p id="_86">86 <a lang="bo">བོར</a> = ['to throw away; to give up or cast aside']</p>
# <p id="_87">87 <a lang="bo">ཅི་སྟེ</a> = ['в случае/но если...?']</p>
# <p id="_88">88 <a lang="bo">བརྩོན</a> = ['vb, to endeavor; make effort; strive; exert oneself; noun: effort; endeavor; exertion']</p>
# <p id="_89">89 <a lang="bo">ཞེས</a> = ['.. - это..']</p>
# <p id="_90">90 <a lang="bo">གསུངས</a> = ['said; mentioned; say; talk H']</p>
# <p id="_91">91 <a lang="bo">འདྲ</a> = ['similar; same; similarity; likeness; like; similar; image']</p>
# <p id="_92">92 <a lang="bo">བླང</a> = ['adopt; adopting; assume; take up; take; receive; assert; assertion']</p>
# <p id="_93">93 <a lang="bo">དོར</a> = ['discard; reject; cast out; forsake; cancel']</p>
# <p id="_94">94 <a lang="bo">འབྱེད</a> = ['to separate; open; separate; differentiate{BJ}; opener{BR}']</p>
# <p id="_95">95 <a lang="bo">ཤེས་རབ</a> = ['nn', 'prajñā', 'проникающее-различающее Знание']</p>
# <p id="_96">96 <a lang="bo">ང</a> = ['я', "adj'ng + nga = comparative"]</p>
# <p id="_97">97 <a lang="bo">བྲལ</a> = ['separation; free from; lack; devoid; separate from']</p>
# <p id="_98">98 <a lang="bo">སུ</a> = ['кто']</p>
# <p id="_99">99 <a lang="bo">བགྲོད</a> = ['progress; get along; advance; proceed; travel; go; traverse; vehicle']</p>
# <p id="_100">100 <a lang="bo">ནུས</a> = ['ability; able; potency; power; capacity']</p>
# <p id="_101">101 <a lang="bo">བརྩེ</a> = ['noun: mercy; love; kindness; vb, feel mercy; pity; love']</p>
# <p id="_102">102 <a lang="bo">གྱུར</a> = ['become; change; transform; arise; be']</p>
# <p id="_103">103 <a lang="bo">སྙིང་རྗེ</a> = ['pretty, nice, beautiful, compassion, kindness, mercy, pity']</p>
# <p id="_104">104 <a lang="bo">གང</a> = ['чего/какой бы', 'который', 'что', 'куда']</p>
# <p id="_105">105 <a lang="bo">ཞིག</a> = ['побуждение', 'призыв - .!', 'кто-либо', 'destroy-past tns', 'второй слог']</p>
# <p id="_106">106 <a lang="bo">ཡོད</a> = ['be', 'live', 'exist', 'have', 'there is', 'has', 'have', 'was', 'matter', 'who were present']</p>
# <p id="_107">107 <a lang="bo">རྨོངས</a> = ['obscuration; delusion; confusion; ignorance; dullness']</p>
# <p id="_108">108 <a lang="bo">བསལ</a> = ['clear away; remove; throw off; eradicate; separate']</p>
# <p id="_109">109 <a lang="bo">འགྲུས</a> = ['zeal; enthusiasm; diligence']</p>
# <p id="_110">110 <a lang="bo">རྩོམ</a> = ['begin; initiate; compose; write a book']</p>
# <p id="_111">111 <a lang="bo">འདི</a> = ['это']</p>
# <p id="_112">112 <a lang="bo">བརྗིད</a> = ['shine; glitter']</p>
# <p id="_113">113 <a lang="bo">རྩལ</a> = ['capacity; manifest capacity; dexterity; power']</p>
# <p id="_114">114 <a lang="bo">ཁུར</a> = ['burden; load']</p>
# <p id="_115">115 <a lang="bo">འཁྱེར</a> = ['to carry; bear; bring']</p>
# <p id="_116">116 <a lang="bo">བྱ</a> = ['1. activity; object; deed; do; action to do; make; perform 2. bird (pas.t.)']</p>
# <p id="_117">117 <a lang="bo">ཙམ</a> = ['approximately, roughly']</p>
# <p id="_118">118 <a lang="bo">གཞོལ</a> = ['to flow {T}']</p>
# <p id="_119">119 <a lang="bo">རྙེད</a> = ['vb, find; gain; discover; noun: goods; property; profit']</p>
# <p id="_120">120 <a lang="bo">ལྟ</a> = ['vb, view; look (pres); see; read noun: view; false view']</p>
# <p id="_121">121 <a lang="bo">ཟ</a> = ['food; to eat (present nh.)']</p>
# <p id="_122">122 <a lang="bo">སྐོམ</a> = ['to feel thirsty']</p>
# <p id="_123">123 <a lang="bo">བྱེད</a> = ['do; act; perform; does; refer (to), to happen (pres.t.)']</p>
# <p id="_124">124 <a lang="bo">འཕགས</a> = ['Superior; noble']</p>
# <p id="_125">125 <a lang="bo">སྣང</a> = ['to appear; perceive; light; illuminate; appearance']</p>
# <p id="_126">126 <a lang="bo">ཡིས</a> = ['cc', 'деятель', 'инструмент', 'c отношением', 'По причине', 'из-за', 'вследствии']</p>
# <p id="_127">127 <a lang="bo">འདེགས</a> = ['support']</p>
# <p id="_128">128 <a lang="bo">དེ་འདྲ</a> = ['like that, so, such, thus']</p>
# <p id="_129">129 <a lang="bo">མཁས</a> = ['wise; skilled; be skillful; scholar']</p>

# %% [markdown]
# ##### 4.а) Запись в HTML

# %%
from IPython.core.display import display, HTML

with open('Result_Lotsawa.html', 'r', encoding='utf-8') as f:
    res_html=f.read()       
    
    #пишем тэги для строки
    res_html=re.sub(r'<section lang="bo">\n([\s\S]*?)</section>', f'<section lang="bo">\n{res_strn}\n</section>',res_html)
    #пишем тэги для словарика
    res_html=re.sub(r'<section class="dict">\n([\s\S]*?)</section>', f'<section class="dict">\n{dct_str}</section>',res_html)

with open('Result_Lotsawa.html', 'w', encoding='utf-8') as wf:   
    wf.write(res_html)

# %% [markdown]
# ##### 4.б) Вывод здесь во фрейме

# %%
from IPython.display import IFrame
IFrame(src='\Result_Lotsawa.html', width=910, height=600)
# Out:
#         <iframe
#             width="910"
#             height="600"
#             src="\Result_Lotsawa.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ___

# %% [markdown]
# c

# %%
my_string=b'\x1f'.decode('utf-8')
print(my_string)  # str
